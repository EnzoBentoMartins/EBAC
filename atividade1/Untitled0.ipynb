# %%
ola = 'Olá mundo.'
print(ola)
# Out:
# Olá mundo.

# %% [markdown]
# ![Captura de tela 2024-01-12 142945.png](data:image/png;base64,...)

# %%
qtv_a = 3
tkt_a = 320.53

a = tkt_a * qtv_a
print(a)
# Out:
# 961.5899999999999

# %%
vtv_b = 834.47
tkt_b = 119.21

b = vtv_b / tkt_b
print(b)
# Out:
# 7.000000000000001

# %%
vtv_c = 15378.12
qtv_c = 5

c = vtv_c / qtv_c
print(c)
# Out:
# 3075.6240000000003

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'
print(cancao.capitalize())
print(cancao.split())
print(cancao.upper())
# Out:
# Roda mundo, roda gigante, roda moinho, roda pião.
# ['Roda', 'mundo,', 'roda', 'gigante,', 'roda', 'moinho,', 'roda', 'pião.']
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; ' + 'é a primeira alta em 6 anos.'
split = noticia.split()

selic = split[3]
print(selic)

ano = split[-2]
print(ano)
# Out:
# 2,75%
# 6

# %%
a = False
b = True

x = not a & b

print(x)
# Out:
# True
