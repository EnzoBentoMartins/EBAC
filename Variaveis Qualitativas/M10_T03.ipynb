# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

prev_renda = pd.read_csv('previsao_de_renda.csv')

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %%
qualit_renda = ['sexo', 'posse_de_veiculo', 'posse_de_imovel', 'tipo_renda', 'educacao', 'estado_civil', 'tipo_residencia', 'mau']

for var in qualit_renda:
    plt.figure(figsize=(12,6))
    plt.title(f'Distribuição de {var} ao longo do tempo')
    sns.countplot(x='data_ref', hue=var, data=prev_renda)
    plt.xlabel('Data')
    plt.ylabel('Contagem')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ### 1 - Unica mudança drastica perceptivel é em educação que a partir de 2015-09-01 há uma diminuição de secundario e um aumento de superior completo

# %% [markdown]
# 2) Para cada variável qualitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %%
for var in qualit_renda:
    plt.figure(figsize=(14, 8))
    plt.xticks(rotation=45)
    mean_df = prev_renda.groupby(['data_ref', var])['renda'].mean().reset_index()
    sns.lineplot(data=mean_df, x='data_ref', y='renda', hue=var, marker='o')
    plt.title(f'Média de distribuição do {var} ao longo do tempo')

# %% [markdown]
# ### 2 - De fato há algumas alterações ao longo do tempo. Podemos sim utilizar essas variaveis em uma modelagem.
